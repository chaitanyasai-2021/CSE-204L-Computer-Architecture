# %% [markdown]
# ### AP21110010200
# ### AP21110010219
# ### AP21110010228
# ### AP21110010253
# ### AP21110010260

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv(r"C:\Users\urjcr\Desktop\glassdoor.csv")

# %%
df.head(20)
# Out:
#                        company  \
# 0                          ABB
# 1                      Philips
# 2                         HSBC
# 3            Facctum Solutions
# 4          JPMorgan Chase & Co
# 5                   Sanfoundry
# 6                       Beinex
# 7                   Sanfoundry
# 8                       Oracle
# 9                      PhonePe
# 10                       Hyqoo
# 11                    BigShyft
# 12                      Findem
# 13                  Sanfoundry
# 14                   News Corp
# 15               Medpace, Inc.
# 16                     Infosys
# 17                   Microsoft
# 18     Skyla Software Solution
# 19  TVS Supply Chain Solutions
#
#                                             job_title  company_rating  \
# 0                                 Junior Data Analyst             4.0
# 1                              Data Scientist - AI/ML             4.0
# 2                                  Data Science GSC’s             3.9
# ...

# %%
df.isnull().sum()
# Out:
# company                          1
# job_title                        0
# company_rating                 244
# job_description                 12
# location                         0
# salary_avg_estimate            264
# salary_estimate_payperiod      264
# company_size                   126
# company_founded                126
# employment_type                126
# industry                       126
# sector                         126
# revenue                        126
# career_opportunities_rating    169
# comp_and_benefits_rating       169
# culture_and_values_rating      169
# senior_management_rating       169
# work_life_balance_rating       169
# dtype: int64

# %%
df[""].value_counts()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Occupation'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
df["EducationLevel"].value_counts()
# Out:
# Bachelors              5261
# Partial College        4966
# High School            3241
# Graduate Degree        3125
# Partial High School    1555
# Name: EducationLevel, dtype: int64

# %%
df.groupby('MaritalStatus')['AnnualIncome'].mean().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='MaritalStatus'>

# %%
df.groupby('EducationLevel')['AnnualIncome'].mean().sort_values(ascending=False).plot.bar()
# Out:
# <AxesSubplot:xlabel='EducationLevel'>

# %%
df.groupby("Gender").AnnualIncome.mean()
# Out:
# Gender
# F    57344.804318
# M    57253.999562
# Name: AnnualIncome, dtype: float64

# %%
sns.boxplot(x="AnnualIncome",data=df)
# Out:
# <AxesSubplot:xlabel='AnnualIncome'>

# %%
sns.boxplot( x="AnnualIncome", y='Gender', data=df, )
plt.show()

# %%
sns.catplot(x="AnnualIncome",y='Occupation',data=df,kind="bar")
